# %% [markdown]
# #**HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for a classification problem. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well known problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.  https://keras.io/

# %% [markdown]
# ##Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layers Neural Network to perfrom classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 



tf.random.set_seed(42)
# os.environ['TF_DETERMINISTIC_OPS']='1'

# %% [markdown]
# ### Load Data: IMDB dataset
#
# In this HW, we use the IMDB dataset that can be easily downloaded using Keras. The dataset contains 50,000 movie reviews from IMDB, labeled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes. For convenience, the words are indexed by the overall frequency in the dataset, so that for example the integer "3" encodes the 3rd most frequent word in the data. For testing purposes, we will only consider the first 10,000  most common words.
# By default, the load_data method returns a breakdown of the dataset into training and test sets. Both these sets contain 25,000 samples. To also have a validation set, we split the test set in half.

# %%
num_words = 1000
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=num_words)
(X_valid, X_test) = X_test[:12500], X_test[12500:]
(y_valid, y_test) = y_test[:12500], y_test[12500:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 1s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# In this HW we will consider a Deep Neural Network. The IMDB data consists in reviews, each one composed by a seqeunce of words. In order to encode each review in a single tensor with a fixed number of elements, we will use multi-hot encoding. Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones. The obtained input representation indicates which words are present (at least one time) in the sentence.

# %%
def multi_hot_encoder(dataset, num_word):
  dataset_multi_hot=[]
  for sequence in dataset:
    index, _ = tf.unique(sequence)
    dataset_multi_hot.append(tf.reduce_max(tf.one_hot(index-1, num_word, dtype=tf.int32), axis=0))
  dataset_multi_hot = tf.stack(dataset_multi_hot)
  return dataset_multi_hot

X_train = multi_hot_encoder(X_train,num_words)
X_test = multi_hot_encoder(X_test,num_words)
X_valid = multi_hot_encoder(X_valid,num_words)

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *   a input layer (tf.keras.Input) that is the first layer in your model. With this layer you should specify the input_shape argument, leaving out the batch size: (num_words,);
# *  a Dense layer (keras.layers.Dense) with 16 neurons, and the "relu" activation function;
# * another Dense layer with 16 neurons, also with the "relu" activation function;
# * a final Dense layer with 1 output neurons, and with the "sigmoid" activation (since we considering a binary classification task).

# %%
model = keras.models.Sequential()
model.add(tf.keras.Input(shape=(num_words,)))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                16016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_imdb_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# Instaed of using *add()* method it is also possibile to define the model using the following syntax

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])
model.summary()
keras.utils.plot_model(model, "my_imdb_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                16016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# Since the model performs a binary classification task, we use the bynary cross-entropy as loss. As optimizer we use Adam.
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epochs to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 782/782 [==============================] - 3s 3ms/step - loss: 0.6691 - accuracy: 0.5917 - val_loss: 0.5086 - val_accuracy: 0.7899
# Epoch 2/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4609 - accuracy: 0.8105 - val_loss: 0.3856 - val_accuracy: 0.8406
# Epoch 3/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3556 - accuracy: 0.8580 - val_loss: 0.3534 - val_accuracy: 0.8515
# Epoch 4/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3298 - accuracy: 0.8647 - val_loss: 0.3407 - val_accuracy: 0.8543
# Epoch 5/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3148 - accuracy: 0.8714 - val_loss: 0.3377 - val_accuracy: 0.8555
# Epoch 6/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3055 - accuracy: 0.8712 - val_loss: 0.3344 - val_accuracy: 0.8565
# Epoch 7/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2989 - accuracy: 0.8771 - val_loss: 0.3344 - val_accuracy: 0.8562
# Epoch 8/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3030 - accuracy: 0.8742 - val_loss: 0.3344 - val_accuracy: 0.8557
# Epoch 9/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2970 - accuracy: 0.8784 - val_loss: 0.3352 - val_accuracy: 0.8549
# Epoch 10/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2928 - accuracy: 0.8781 - val_loss: 0.3355 - val_accuracy: 0.8552
# Epoch 11/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2966 - accuracy: 0.8797 - val_loss: 0.3366 - val_accuracy: 0.8539
# Epoch 12/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2865 - accuracy: 0.8849 - val_loss: 0.3373 - val_accuracy: 0.8549
# Epoch 13/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2954 - accuracy: 0.8803 - val_loss: 0.3393 - val_accuracy: 0.8543
# Epoch 14/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2856 - accuracy: 0.8837 - val_loss: 0.3387 - val_accuracy: 0.8536
# Epoch 15/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2884 - accuracy: 0.8822 - val_loss: 0.3398 - val_accuracy: 0.8538
# Epoch 16/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2878 - accuracy: 0.8806 - val_loss: 0.3405 - val_accuracy: 0.8534
# Epoch 17/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2871 - accuracy: 0.8821 - val_loss: 0.3418 - val_accuracy: 0.8546
# Epoch 18/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2822 - accuracy: 0.8861 - val_loss: 0.3427 - val_accuracy: 0.8542
# Epoch 19/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2847 - accuracy: 0.8863 - val_loss: 0.3433 - val_accuracy: 0.8526
# Epoch 20/20
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2792 - accuracy: 0.8863 - val_loss: 0.3445 - val_accuracy: 0.8531

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_acc_and_loss" function because we will reuse it in the next steps.

# %%
def plot_learning_acc_and_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_acc_and_loss(history)

# %% [markdown]
# ### [TO COMPLETE] Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 391/391 [==============================] - 0s 1ms/step - loss: 0.3227 - accuracy: 0.8662
# [0.3226569592952728, 0.8662400245666504]

# %% [markdown]
# [TO COMPLETE] Explain why it is important to use test and validation, and why it is important to evaluate the model on the test set instead of the validation set. Finally, explain which is the usefulness of the validation set. Insert the discussion in this cell.
#
# Evaluating the error only on the training set, we risk to overfit. Then we use a validation and a test sets to evaluate the error on examples that aren't used during the training phase. It's important that the evaluation of the model is done on the test set, because it gives an approximation of the generalization error. The validation set is used to find the hyperparameters of the model and it gives a lower bound of the generalization errors and it express if the model trained on the training set overfits.

# %% [markdown]
# ## [TO COMPLETE] Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..
#
# [TO COMPLETE] In the next cell define a new model (similar to the previuos one) that overfits the training data; then plot the trend of the loss in training and validation set.

# %%
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(15, activation="relu"),
    keras.layers.Dense(15, activation="relu"),
    keras.layers.Dense(15, activation="sigmoid"),
    keras.layers.Dense(15, activation="sigmoid"),
    keras.layers.Dense(1, activation="sigmoid")
])
#[TO COMPLETE] modify the previuos model in order to obtain a new mdel that overfit the training data

model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=80,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/80
# 782/782 [==============================] - 3s 3ms/step - loss: 0.5501 - accuracy: 0.7239 - val_loss: 0.3475 - val_accuracy: 0.8526
# Epoch 2/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3262 - accuracy: 0.8672 - val_loss: 0.3365 - val_accuracy: 0.8532
# Epoch 3/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2989 - accuracy: 0.8775 - val_loss: 0.3390 - val_accuracy: 0.8485
# Epoch 4/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2992 - accuracy: 0.8738 - val_loss: 0.3453 - val_accuracy: 0.8458
# Epoch 5/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2912 - accuracy: 0.8788 - val_loss: 0.3366 - val_accuracy: 0.8508
# Epoch 6/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2785 - accuracy: 0.8813 - val_loss: 0.3413 - val_accuracy: 0.8511
# Epoch 7/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2617 - accuracy: 0.8853 - val_loss: 0.3550 - val_accuracy: 0.8470
# Epoch 8/80
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2547 - accuracy: 0.8911 - val_loss: 0.3606 - val_accuracy: 0.8486
# Epoch 9/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2356 - accuracy: 0.9008 - val_loss: 0.3717 - val_accuracy: 0.8471
# Epoch 10/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2182 - accuracy: 0.9077 - val_loss: 0.4014 - val_accuracy: 0.8400
# Epoch 11/80
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2071 - accuracy: 0.9148 - val_loss: 0.4369 - val_accuracy: 0.8374
# Epoch 12/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1866 - accuracy: 0.9286 - val_loss: 0.4477 - val_accuracy: 0.8353
# Epoch 13/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1791 - accuracy: 0.9318 - val_loss: 0.4769 - val_accuracy: 0.8344
# Epoch 14/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1504 - accuracy: 0.9440 - val_loss: 0.4965 - val_accuracy: 0.8275
# Epoch 15/80
# 782/782 [==============================] - 2s 2ms/step - loss: 0.1387 - accuracy: 0.9507 - val_loss: 0.5322 - val_accuracy: 0.8253
# Epoch 16/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1329 - accuracy: 0.9567 - val_loss: 0.5572 - val_accuracy: 0.8225
# Epoch 17/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1152 - accuracy: 0.9633 - val_loss: 0.5841 - val_accuracy: 0.8238
# Epoch 18/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.1037 - accuracy: 0.9692 - val_loss: 0.6253 - val_accuracy: 0.8238
# Epoch 19/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0992 - accuracy: 0.9720 - val_loss: 0.6297 - val_accuracy: 0.8190
# Epoch 20/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0888 - accuracy: 0.9748 - val_loss: 0.6624 - val_accuracy: 0.8155
# Epoch 21/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0912 - accuracy: 0.9764 - val_loss: 0.6766 - val_accuracy: 0.8150
# Epoch 22/80
# 782/782 [==============================] - 2s 2ms/step - loss: 0.0741 - accuracy: 0.9821 - val_loss: 0.7003 - val_accuracy: 0.8144
# Epoch 23/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0644 - accuracy: 0.9849 - val_loss: 0.7230 - val_accuracy: 0.8146
# Epoch 24/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0648 - accuracy: 0.9848 - val_loss: 0.7158 - val_accuracy: 0.8146
# Epoch 25/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0601 - accuracy: 0.9864 - val_loss: 0.7381 - val_accuracy: 0.8134
# Epoch 26/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0649 - accuracy: 0.9859 - val_loss: 0.7660 - val_accuracy: 0.8147
# Epoch 27/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0598 - accuracy: 0.9858 - val_loss: 0.7548 - val_accuracy: 0.8199
# Epoch 28/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0654 - accuracy: 0.9834 - val_loss: 0.7631 - val_accuracy: 0.8118
# Epoch 29/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0491 - accuracy: 0.9896 - val_loss: 0.7697 - val_accuracy: 0.8176
# Epoch 30/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0515 - accuracy: 0.9875 - val_loss: 0.7770 - val_accuracy: 0.8114
# Epoch 31/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0488 - accuracy: 0.9909 - val_loss: 0.7913 - val_accuracy: 0.8173
# Epoch 32/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0521 - accuracy: 0.9882 - val_loss: 0.7877 - val_accuracy: 0.8150
# Epoch 33/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0513 - accuracy: 0.9890 - val_loss: 0.7912 - val_accuracy: 0.8119
# Epoch 34/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0489 - accuracy: 0.9882 - val_loss: 0.8028 - val_accuracy: 0.8067
# Epoch 35/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0385 - accuracy: 0.9928 - val_loss: 0.8133 - val_accuracy: 0.8110
# Epoch 36/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0417 - accuracy: 0.9925 - val_loss: 0.8314 - val_accuracy: 0.8126
# Epoch 37/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0487 - accuracy: 0.9896 - val_loss: 0.8083 - val_accuracy: 0.8121
# Epoch 38/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0466 - accuracy: 0.9896 - val_loss: 0.8035 - val_accuracy: 0.8092
# Epoch 39/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0430 - accuracy: 0.9918 - val_loss: 0.8082 - val_accuracy: 0.8140
# Epoch 40/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0420 - accuracy: 0.9905 - val_loss: 0.8128 - val_accuracy: 0.8115
# Epoch 41/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0401 - accuracy: 0.9924 - val_loss: 0.8270 - val_accuracy: 0.8110
# Epoch 42/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0437 - accuracy: 0.9912 - val_loss: 0.8401 - val_accuracy: 0.8138
# Epoch 43/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0392 - accuracy: 0.9915 - val_loss: 0.8217 - val_accuracy: 0.8111
# Epoch 44/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0449 - accuracy: 0.9895 - val_loss: 0.8194 - val_accuracy: 0.8143
# Epoch 45/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0444 - accuracy: 0.9900 - val_loss: 0.8130 - val_accuracy: 0.8102
# Epoch 46/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.
80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0304 - accuracy: 0.9945 - val_loss: 0.8948 - val_accuracy: 0.8095
# Epoch 78/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0438 - accuracy: 0.9900 - val_loss: 0.8890 - val_accuracy: 0.8046
# Epoch 79/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0374 - accuracy: 0.9925 - val_loss: 0.8773 - val_accuracy: 0.8092
# Epoch 80/80
# 782/782 [==============================] - 2s 3ms/step - loss: 0.0293 - accuracy: 0.9948 - val_loss: 0.8849 - val_accuracy: 0.8098
# Model Evaluation
# 391/391 [==============================] - 0s 1ms/step - loss: 0.8157 - accuracy: 0.8264
# [0.8156917095184326, 0.8263999819755554]

# %% [markdown]
# Define the plot_learning_curves function that plots inly the losses (not the accuracy).

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.epoch,history.history['loss'], label='train loss')
    plt.plot(history.epoch,history.history['val_loss'], label='valid loss')
    plt.legend()
    plt.title('loss')
    plt.grid(True)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### [TO COMPLETE] L1 norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow to remove the overfitting effect.

# %%
#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfroms the L1-norm regularization

#[TO COMPLETE] copy the model that you previously defined that overfits the 
#trainnig data, and add the L1-norm regularization. Use a proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1 

#In general, a layer that exploits L1-norm regularization is defined as follows:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE], kernel_regularizer=tf.keras.regularizers.l1([TO COMPLETE]))) 

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(15, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
    keras.layers.Dense(15, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
    keras.layers.Dense(15, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
    keras.layers.Dense(15, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
    keras.layers.Dense(1, activation="sigmoid")
])


model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/40
# 782/782 [==============================] - 3s 3ms/step - loss: 0.7569 - accuracy: 0.6134 - val_loss: 0.4740 - val_accuracy: 0.8406
# Epoch 2/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4520 - accuracy: 0.8558 - val_loss: 0.4421 - val_accuracy: 0.8511
# Epoch 3/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4115 - accuracy: 0.8727 - val_loss: 0.4472 - val_accuracy: 0.8458
# Epoch 4/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4107 - accuracy: 0.8672 - val_loss: 0.4458 - val_accuracy: 0.8440
# Epoch 5/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4052 - accuracy: 0.8721 - val_loss: 0.4311 - val_accuracy: 0.8490
# Epoch 6/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3982 - accuracy: 0.8711 - val_loss: 0.4201 - val_accuracy: 0.8550
# Epoch 7/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.
40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3503 - accuracy: 0.8814 - val_loss: 0.4050 - val_accuracy: 0.8515
# Epoch 39/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3609 - accuracy: 0.8774 - val_loss: 0.4092 - val_accuracy: 0.8505
# Epoch 40/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3542 - accuracy: 0.8821 - val_loss: 0.4078 - val_accuracy: 0.8485
# Model Evaluation
# 391/391 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8595

# %% [markdown]
# ### [TO COMPLETE] L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainig data, and add the L2-norm regularization. Use proper values for the
#alpha hyper-parameters, that prevents the model from overfitting. The results  
#reached by the model in terms of loss and accuracy (in all data sets) should be
#comparable with the ones obtained by the initial model defined in Exercise 2.1

#In general, a layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=[TO COMPLETE], activation=[TO COMPLETE],kernel_regularizer=tf.keras.regularizers.l2([TO COMPLETE]))) 

model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(15, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.005)),
    keras.layers.Dense(15, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.005)),
    keras.layers.Dense(15, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l2(0.005)),
    keras.layers.Dense(15, activation="sigmoid", kernel_regularizer=tf.keras.regularizers.l2(0.005)),
    keras.layers.Dense(1, activation="sigmoid")
])

model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate
              metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid))

print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/40
# 782/782 [==============================] - 3s 3ms/step - loss: 0.8073 - accuracy: 0.6529 - val_loss: 0.5279 - val_accuracy: 0.8481
# Epoch 2/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5158 - accuracy: 0.8495 - val_loss: 0.4941 - val_accuracy: 0.8466
# Epoch 3/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4748 - accuracy: 0.8618 - val_loss: 0.4880 - val_accuracy: 0.8432
# Epoch 4/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4653 - accuracy: 0.8580 - val_loss: 0.4863 - val_accuracy: 0.8394
# Epoch 5/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4549 - accuracy: 0.8606 - val_loss: 0.4773 - val_accuracy: 0.8391
# Epoch 6/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4476 - accuracy: 0.8603 - val_loss: 0.4551 - val_accuracy: 0.8536
# Epoch 7/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4368 - accuracy: 0.8653 - val_loss: 0.4495 - val_accuracy: 0.8546
# Epoch 8/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4388 - accuracy: 0.8623 - val_loss: 0.4482 - val_accuracy: 0.8510
# Epoch 9/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4285 - accuracy: 0.8656 - val_loss: 0.4442 - val_accuracy: 0.8538
# Epoch 10/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4251 - accuracy: 0.8664 - val_loss: 0.4421 - val_accuracy: 0.8533
# Epoch 11/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4257 - accuracy: 0.8661 - val_loss: 0.4518 - val_accuracy: 0.8476
# Epoch 12/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4173 - accuracy: 0.8679 - val_loss: 0.4387 - val_accuracy: 0.8542
# Epoch 13/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4240 - accuracy: 0.8653 - val_loss: 0.4371 - val_accuracy: 0.8546
# Epoch 14/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4150 - accuracy: 0.8685 - val_loss: 0.4425 - val_accuracy: 0.8474
# Epoch 15/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4164 - accuracy: 0.8657 - val_loss: 0.4321 - val_accuracy: 0.8538
# Epoch 16/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4142 - accuracy: 0.8643 - val_loss: 0.4332 - val_accuracy: 0.8514
# Epoch 17/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4148 - accuracy: 0.8650 - val_loss: 0.4291 - val_accuracy: 0.8563
# Epoch 18/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4126 - accuracy: 0.8650 - val_loss: 0.4336 - val_accuracy: 0.8515
# Epoch 19/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4133 - accuracy: 0.8656 - val_loss: 0.4254 - val_accuracy: 0.8562
# Epoch 20/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4077 - accuracy: 0.8671 - val_loss: 0.4299 - val_accuracy: 0.8522
# Epoch 21/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4093 - accuracy: 0.8680 - val_loss: 0.4237 - val_accuracy: 0.8561
# Epoch 22/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4091 - accuracy: 0.8646 - val_loss: 0.4235 - val_accuracy: 0.8569
# Epoch 23/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4009 - accuracy: 0.8707 - val_loss: 0.4339 - val_accuracy: 0.8477
# Epoch 24/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4028 - accuracy: 0.8676 - val_loss: 0.4240 - val_accuracy: 0.8538
# Epoch 25/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3991 - accuracy: 0.8690 - val_loss: 0.4220 - val_accuracy: 0.8538
# Epoch 26/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4039 - accuracy: 0.8691 - val_loss: 0.4293 - val_accuracy: 0.8518
# Epoch 27/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4022 - accuracy: 0.8663 - val_loss: 0.4204 - val_accuracy: 0.8546
# Epoch 28/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3978 - accuracy: 0.8711 - val_loss: 0.4224 - val_accuracy: 0.8555
# Epoch 29/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3978 - accuracy: 0.8661 - val_loss: 0.4177 - val_accuracy: 0.8550
# Epoch 30/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8704 - val_loss: 0.4430 - val_accuracy: 0.8400
# Epoch 31/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3968 - accuracy: 0.8684 - val_loss: 0.4175 - val_accuracy: 0.8566
# Epoch 32/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4015 - accuracy: 0.8661 - val_loss: 0.4167 - val_accuracy: 0.8574
# Epoch 33/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3970 - accuracy: 0.8685 - val_loss: 0.4189 - val_accuracy: 0.8552
# Epoch 34/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4018 - accuracy: 0.8642 - val_loss: 0.4268 - val_accuracy: 0.8504
# Epoch 35/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3934 - accuracy: 0.8670 - val_loss: 0.4192 - val_accuracy: 0.8541
# Epoch 36/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4023 - accuracy: 0.8662 - val_loss: 0.4226 - val_accuracy: 0.8511
# Epoch 37/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3963 - accuracy: 0.8673 - val_loss: 0.4207 - val_accuracy: 0.8550
# Epoch 38/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3937 - accuracy: 0.8726 - val_loss: 0.4159 - val_accuracy: 0.8574
# Epoch 39/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3995 - accuracy: 0.8655 - val_loss: 0.4167 - val_accuracy: 0.8558
# Epoch 40/40
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8665 - val_loss: 0.4172 - val_accuracy: 0.8534
# Model Evaluation
# 391/391 [==============================] - 0s 1ms/step - loss: 0.4000 - accuracy: 0.8636

# %% [markdown]
# ###[TO COMPLETE] Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
#[TO COMPLETE] insert the model that you previously defined that overfit the 
#trainnig data
model = keras.models.Sequential([
    tf.keras.Input(shape=(num_words,)),
    keras.layers.Dense(15, activation="relu"),
    keras.layers.Dense(15, activation="relu"),
    keras.layers.Dense(15, activation="sigmoid"),
    keras.layers.Dense(15, activation="sigmoid"),
    keras.layers.Dense(1, activation="sigmoid")
])


model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),#[TO COMPLETE] learning rate

              metrics=["accuracy"])

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=4),#[TO COMPLETE] play with patience and find the value that prevents the model from overfitting.


    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train, y_train, epochs=40,#[TO COMPLETE] epochs
                    validation_data=(X_valid, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/40
# 782/782 [==============================] - 3s 3ms/step - loss: 0.6661 - accuracy: 0.6166 - val_loss: 0.3762 - val_accuracy: 0.8537
# Epoch 2/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3523 - accuracy: 0.8620 - val_loss: 0.3453 - val_accuracy: 0.8552
# Epoch 3/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3055 - accuracy: 0.8784 - val_loss: 0.3416 - val_accuracy: 0.8506
# Epoch 4/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2974 - accuracy: 0.8785 - val_loss: 0.3489 - val_accuracy: 0.8475
# Epoch 5/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2797 - accuracy: 0.8881 - val_loss: 0.3452 - val_accuracy: 0.8543
# Epoch 6/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2571 - accuracy: 0.8941 - val_loss: 0.3598 - val_accuracy: 0.8485
# Epoch 7/40
# 782/782 [==============================] - 2s 3ms/step - loss: 0.2291 - accuracy: 0.9073 - val_loss: 0.3731 - val_accuracy: 0.8431
# Model Evaluation
# 391/391 [==============================] - 1s 1ms/step - loss: 0.3206 - accuracy: 0.8638

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit (the network weights). The aim of model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learning rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(16, activation="relu"),
                                    keras.layers.Dense(1, activation="sigmoid")
                                     ])
    model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train, y_train,
                        validation_data=(X_valid, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
    print("evaluation on test set")
    model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6574 - accuracy: 0.6164 - val_loss: 0.4903 - val_accuracy: 0.8023
# Epoch 2/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4390 - accuracy: 0.8208 - val_loss: 0.3797 - val_accuracy: 0.8400
# Epoch 3/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3435 - accuracy: 0.8584 - val_loss: 0.3525 - val_accuracy: 0.8516
# Epoch 4/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3223 - accuracy: 0.8639 - val_loss: 0.3422 - val_accuracy: 0.8572
# Epoch 5/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3102 - accuracy: 0.8711 - val_loss: 0.3393 - val_accuracy: 0.8575
# Epoch 6/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3011 - accuracy: 0.8739 - val_loss: 0.3370 - val_accuracy: 0.8574
# Epoch 7/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2955 - accuracy: 0.8781 - val_loss: 0.3374 - val_accuracy: 0.8567
# Epoch 8/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3010 - accuracy: 0.8760 - val_loss: 0.3376 - val_accuracy: 0.8552
# evaluation on test set
# 391/391 [==============================] - 1s 1ms/step - loss: 0.3168 - accuracy: 0.8667
# Epoch 1/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4112 - accuracy: 0.8107 - val_loss: 0.3407 - val_accuracy: 0.8456
# Epoch 2/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.3182 - accuracy: 0.8611 - val_loss: 0.3357 - val_accuracy: 0.8537
# Epoch 3/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2860 - accuracy: 0.8778 - val_loss: 0.3504 - val_accuracy: 0.8486
# Epoch 4/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.2743 - accuracy: 0.8811 - val_loss: 0.3567 - val_accuracy: 0.8488
# evaluation on test set
# 391/391 [==============================] - 0s 1ms/step - loss: 0.3323 - accuracy: 0.8594
# Epoch 1/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5728 - accuracy: 0.7231 - val_loss: 0.6751 - val_accuracy: 0.5219
# Epoch 2/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.5911 - val_loss: 0.5647 - val_accuracy: 0.7594
# Epoch 3/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7607 - val_loss: 0.4968 - val_accuracy: 0.8031
# Epoch 4/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.5078 - accuracy: 0.7964 - val_loss: 0.5320 - val_accuracy: 0.7770
# Epoch 5/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4991 - accuracy: 0.7889 - val_loss: 0.5705 - val_accuracy: 0.7273
# evaluation on test set
# 391/391 [==============================] - 1s 1ms/step - loss: 0.5629 - accuracy: 0.7274

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_acc_and_loss(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# ### [TO COMPLETE] GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use the GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_neurons, learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time requirements of the process we will consider only these two hyper-paramters.
#
# [TO COMPLETE] in the following code cell define the build_model function.

# %%
def build_model(n_units=30, learning_rate=1e-3):
    # The function has to build a model similar to the ones we used in previuous execises:
    #- a input layer 
    #- one or two Dense layers composed of n_units and that exploit Relu activation function 
    #- the output layer that uses the sigmoid activation function
    # Then, the model has to be compiled.
    model = keras.models.Sequential([
                                    tf.keras.Input(shape=(num_words,)),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(1, activation="sigmoid")
                                     ])
    
    # [TO COMPLETE] Then, the model has to be compiled.
    model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
              metrics=["accuracy"])
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [10, 15, 20],# [TO COMPLETE] insert a list that contains few (2 or 3) reasonable value
    "learning_rate": [1e-3, 1e-4, 1e-5] #[TO COMPLETE] insert a list that contains few (2 or 3) reasonable values
    #Check how the time required to perform GRID search increases when increasing the number of values for each hyper-parameter.
}

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train.numpy(), y_train, epochs=5,#The number of epochs can be modified (check what happens by increasing it)
                validation_data=(X_valid.numpy(), y_valid))
# Out:
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7086 - val_loss: 0.3440 - val_accuracy: 0.8537
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3087 - accuracy: 0.8720 - val_loss: 0.3431 - val_accuracy: 0.8534
# Epoch 3/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3030 - accuracy: 0.8739 - val_loss: 0.3486 - val_accuracy: 0.8535
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2998 - accuracy: 0.8748 - val_loss: 0.3421 - val_accuracy: 0.8505
# Epoch 5/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2812 - accuracy: 0.8848 - val_loss: 0.3584 - val_accuracy: 0.8466
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3511 - accuracy: 0.8568
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5014 - accuracy: 0.7498 - val_loss: 0.3389 - val_accuracy: 0.8562
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3125 - accuracy: 0.8728 - val_loss: 0.3374 - val_accuracy: 0.8549
# Epoch 3/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3065 - accuracy: 0.8737 - val_loss: 0.3399 - val_accuracy: 0.8514
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2953 - accuracy: 0.8750 - val_loss: 0.3359 - val_accuracy: 0.8530
# Epoch 5/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2768 - accuracy: 0.8829 - val_loss: 0.3408 - val_accuracy: 0.8518
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3315 - accuracy: 0.8600
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5259 - accuracy: 0.7232 - val_loss: 0.3382 - val_accuracy: 0.8541
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3122 - accuracy: 0.8722 - val_loss: 0.3373 - val_accuracy: 0.8539
# Epoch 3/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3050 - accuracy: 0.8728 - val_loss: 0.3448 - val_accuracy: 0.8519
# Epoch 4/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2927 - accuracy: 0.8811 - val_loss: 0.3477 - val_accuracy: 0.8510
# Epoch 5/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2721 - accuracy: 0.8896 - val_loss: 0.3589 - val_accuracy: 0.8461
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3603 - accuracy: 0.8470
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5191 - accuracy: 0.7308 - val_loss: 0.3451 - val_accuracy: 0.8534
# Epoch 2/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3122 - accuracy: 0.8692 - val_loss: 0.3382 - val_accuracy: 0.8553
# Epoch 3/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3045 - accuracy: 0.8719 - val_loss: 0.3441 - val_accuracy: 0.8486
# Epoch 4/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3004 - accuracy: 0.8762 - val_loss: 0.3402 - val_accuracy: 0.8528
# Epoch 5/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2792 - accuracy: 0.8831 - val_loss: 0.3420 - val_accuracy: 0.8516
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3375 - accuracy: 0.8552
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5104 - accuracy: 0.7327 - val_loss: 0.3560 - val_accuracy: 0.8457
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3222 - accuracy: 0.8672 - val_loss: 0.3450 - val_accuracy: 0.8502
# Epoch 3/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3066 - accuracy: 0.8701 - val_loss: 0.3498 - val_accuracy: 0.8489
# Epoch 4/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3001 - accuracy: 0.8766 - val_loss: 0.3402 - val_accuracy: 0.8520
# Epoch 5/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2801 - accuracy: 0.8864 - val_loss: 0.3423 - val_accuracy: 0.8470
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8576
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4950 - accuracy: 0.7504 - val_loss: 0.3409 - val_accuracy: 0.8530
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3049 - accuracy: 0.8730 - val_loss: 0.3383 - val_accuracy: 0.8514
# Epoch 3/5
# 625/625 [==============================] - 1s 2ms/step - loss: 0.2883 - accuracy: 0.8776 - val_loss: 0.3442 - val_accuracy: 0.8516
# Epoch 4/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2737 - accuracy: 0.8862 - val_loss: 0.3487 - val_accuracy: 0.8498
# Epoch 5/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.2417 - accuracy: 0.8992 - val_loss: 0.3692 - val_accuracy: 0.8433
# 157/157 [==============================] - 0s 1ms/step - loss: 0.3640 - accuracy: 0.8512
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6497 - accuracy: 0.6447 - val_loss: 0.6354 - val_accuracy: 0.6666
# Epoch 5/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6247 - accuracy: 0.6813 - val_loss: 0.6117 - val_accuracy: 0.6990
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6084 - accuracy: 0.7162
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7157 - accuracy: 0.5020 - val_loss: 0.6971 - val_accuracy: 0.5095
# Epoch 2/5
# 625/625 [==============================] - 2s 2ms/step - loss: 0.6908 - accuracy: 0.5319 - val_loss: 0.6848 - val_accuracy: 0.5526
# Epoch 3/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6794 - accuracy: 0.5725 - val_loss: 0.6748 - val_accuracy: 0.5909
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6689 - accuracy: 0.6042 - val_loss: 0.6626 - val_accuracy: 0.6270
# Epoch 5/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6545 - accuracy: 0.6450 - val_loss: 0.6472 - val_accuracy: 0.6570
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6431 - accuracy: 0.6760
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6992 - accuracy: 0.4916 - val_loss: 0.6892 - val_accuracy: 0.5353
# Epoch 2/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6886 - accuracy: 0.5392 - val_loss: 0.6812 - val_accuracy: 0.5760
# Epoch 3/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6795 - accuracy: 0.5848 - val_loss: 0.6710 - val_accuracy: 0.6157
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6678 - accuracy: 0.6251 - val_loss: 0.6569 - val_accuracy: 0.6544
# Epoch 5/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6515 - accuracy: 0.6691 - val_loss: 0.6377 - val_accuracy: 0.6929
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6403 - accuracy: 0.6846
# Epoch 1/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.7014 - accuracy: 0.5108 - val_loss: 0.6896 - val_accuracy: 0.5369
# Epoch 2/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6855 - accuracy: 0.5550 - val_loss: 0.6802 - val_accuracy: 0.5767
# Epoch 3/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6759 - accuracy: 0.5871 - val_loss: 0.6681 - val_accuracy: 0.6146
# Epoch 4/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6600 - accuracy: 0.6366 - val_loss: 0.6516 - val_accuracy: 0.6473
# Epoch 5/5
# 625/625 [==============================] - 2s 3ms/step - loss: 0.6418 - accuracy: 0.6658 - val_loss: 0.6321 - val_accuracy: 0.6809
# 157/157 [==============================] - 0s 1ms/step - loss: 0.6316 - accuracy: 0.6780
# Epoch 1/5
# 782/782 [==============================] - 2s 3ms/step - loss: 0.6449 - accuracy: 0.6388 - val_loss: 0.4601 - val_accuracy: 0.8085
# Epoch 2/5
# 782/782 [==============================] - 2s 3ms/step - loss: 0.4212 - accuracy: 0.8277 - val_loss: 0.3700 - val_accuracy: 0.8434
# Epoch 3/5
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3391 - accuracy: 0.8612 - val_loss: 0.3475 - val_accuracy: 0.8509
# Epoch 4/5
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3236 - accuracy: 0.8656 - val_loss: 0.3388 - val_accuracy: 0.8562
# Epoch 5/5
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3099 - accuracy: 0.8726 - val_loss: 0.3376 - val_accuracy: 0.8566
# GridSearchCV(cv=None, error_score=nan,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x7f56abc62610>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.0001, 1e-05],
#                          'n_units': [10, 15, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Print the best hyper-parameters, and evealuate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test, y_test)
# Out:
# {'learning_rate': 0.0001, 'n_units': 20}
# 391/391 [==============================] - 1s 1ms/step - loss: 0.3208 - accuracy: 0.8634
# [0.320785790681839, 0.8634399771690369]
